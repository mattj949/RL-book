# %%
from dataclasses import dataclass
from typing import Tuple, Dict, Mapping
from rl.markov_decision_process import FiniteMarkovDecisionProcess
from rl.policy import FiniteDeterministicPolicy
from rl.markov_process import FiniteMarkovProcess, FiniteMarkovRewardProcess
from rl.distribution import Categorical
from scipy.stats import poisson

# %%
@dataclass(frozen=True)
class InventoryState:
    A_on_hand: int
    A_on_order: int
    
    B_on_hand: int
    B_on_order: int

    def A_inventory_position(self) -> int:
        return self.A_on_hand + self.A_on_order
    
    def B_inventory_position(self) -> int:
        return self.B_on_hand + self.B_on_order


InvOrderMapping = Mapping[
    InventoryState,
    Mapping[int, Categorical[Tuple[InventoryState, float]]]
]

# %%
class TwoStoreMDP(FiniteMarkovDecisionProcess[InventoryState, int]):

    def __init__(
        self,
        A_capacity: int,
        A_poisson_lambda: float,
        A_holding_cost: float,
        A_stockout_cost: float,
        
        B_capacity: int,
        B_poisson_lambda: float,
        B_holding_cost: float,
        B_stockout_cost: float,
        
        supplier_cost: float,
        transfer_cost: float
        
    ):
        self.A_capacity: int = A_capacity
        self.A_poisson_lambda: float = A_poisson_lambda
        self.A_holding_cost: float = A_holding_cost
        self.A_stockout_cost: float = A_stockout_cost
        self.A_poisson_distr = poisson(A_poisson_lambda)
        
        self.B_capacity: int = B_capacity
        self.B_poisson_lambda: float = B_poisson_lambda
        self.B_holding_cost: float = B_holding_cost
        self.B_stockout_cost: float = B_stockout_cost
        self.B_poisson_distr = poisson(B_poisson_lambda)
        
        self.supplier_cost: float = supplier_cost
        self.transfer_cost: float = transfer_cost
        
        
        super().__init__(self.get_action_transition_reward_map())

    def get_action_transition_reward_map(self) -> InvOrderMapping:
        
        # Instead of State X order -->
        
        # State X Tuple(A_order_supplier, B_order_supplier, A_to_B_transfer)
        
        d: Dict[InventoryState, Dict[Tuple[int, int, int], Categorical[Tuple[InventoryState,
                                                            float]]]] = {}
        # A_alpha = Inventory in Store A
        for A_alpha in range(self.A_capacity + 1):
            # A_beta = inventory on truck from supplier (order from prev day)
            for A_beta in range(self.A_capacity + 1 - A_alpha):
                # B_alpha = Inventory in Store B
                for B_alpha in range(self.B_capacity + 1):
                    #B_beta = inventory on truck from supplier (order from prev day)
                    for B_beta in range(self.B_capacity + 1 - B_alpha):
                        state: InventoryState = InventoryState(A_alpha, A_beta, B_alpha, B_beta)
                        
                        A_ip: int = state.A_inventory_position()
                        B_ip: int = state.B_inventory_position()
                        
                        A_base_reward: float = -self.A_holding_cost * A_alpha + \
                                                -self.supplier_cost * A_beta
                        B_base_reward: float = -self.B_holding_cost * B_alpha + \
                                                -self.supplier_cost * B_beta
                    
                        
                        # We can transfer between stores, and this happens 
                        # "instantaneously" between periods.
                        # For C-(A+B), we can split this up between an order to
                        # the supplier, and order to the other store. 
                        # Each combination incurs a different price. 
                        
                        max_from_A: int = A_ip
                        max_to_A: int = B_ip
                        
                        max_from_B: int = B_ip
                        max_to_B: int = A_ip
                        
                        for A_to_B in range(-min(max_from_B, max_to_A), min(max_from_A,max_to_B)):
                            transfer_reward = -self.transfer_cost * A_to_B
                            
                            A_ip_new: int = A_ip - A_to_B
                            B_ip_new: int = B_ip + A_to_B
                            
                            total_base_reward = A_base_reward + B_base_reward + transfer_reward
                            
                           
                            d1: Dict[Tuple[int,int,int], Categorical[Tuple[InventoryState, float]]] = {}

                            for A_order in range(self.A_capacity - A_ip_new + 1):
                                for B_order in range(self.B_capacity - B_ip_new + 1):
                                    
                                    group_order = (A_order, B_order, A_to_B)
                                    
                                    # Probabilities of next states with NO stockout
                                    sr_probs_dict: Dict[Tuple[InventoryState, float], float] =\
                                        {(InventoryState(A_ip_new - i, A_order, B_ip_new - j, B_order), total_reward):
                                         self.A_poisson_distr.pmf(i) * self.B_poisson_distr.pmf(j) 
                                         for i in range(A_ip_new) for j in range(B_ip_new)}
                                    
                                    # Probabilities of stockout
                                    A_probability: float = 1 - self.A_poisson_distr.cdf(A_ip_new - 1) 
                                    B_probability: float = 1 - self.B_poisson_distr.cdf(B_ip_new - 1) 
                                    
                                    total_reward: float = total_base_reward - self.A_stockout_cost *\
                                        (A_probability * (self.A_poisson_lambda - A_ip_new) +
                                         A_ip_new * self.A_poisson_distr.pmf(A_ip_new)) +\
                                        - self.B_stockout_cost *\
                                        (B_probability * (self.B_poisson_lambda - B_ip_new) +
                                         B_ip_new * self.B_poisson_distr.pmf(B_ip_new))
                                    
                                    
                                    # Add in stockout for A
                                    sr_probs_dict.update({(InventoryState(0, A_order, j, B_order), total_reward):
                                        A_probability * self.B_poisson_distr.pmf(j) for j in range(B_ip_new)})
                                                
                                    # Add stockout for B
                                    sr_probs_dict.update({(InventoryState(i, A_order, 0, B_order), total_reward):
                                        B_probability * self.A_poisson_distr.pmf(i) for i in range(A_ip_new)})
                                     
                                    # Combined stockout
                                    sr_probs_dict.update({(InventoryState(0, A_order, 0, B_order), total_reward):
                                        B_probability * A_probability})
                                    
                                                      
                                                      
                                                      
                                    d1[group_order] = Categorical(sr_probs_dict)

                            d[state] = d1
        return d

# %%
if __name__ == '__main__':
    from pprint import pprint

    user_A_capacity = 2
    user_A_poisson_lambda = 1.0
    user_A_holding_cost = 1.0
    user_A_stockout_cost = 10.0
    
    user_B_capacity = 3
    user_B_poisson_lambda = 0.8
    user_B_holding_cost = 0.8
    user_B_stockout_cost = 12.0
    
    user_supplier_cost = 0.4
    user_transfer_cost = 0.1

    user_gamma = 0.9

    si_mdp: FiniteMarkovDecisionProcess[InventoryState, int] =\
        TwoStoreMDP(
            A_capacity=user_A_capacity,
            A_poisson_lambda=user_A_poisson_lambda,
            A_holding_cost=user_A_holding_cost,
            A_stockout_cost=user_A_stockout_cost,
        
            B_capacity=user_B_capacity,
            B_poisson_lambda=user_B_poisson_lambda,
            B_holding_cost=user_B_holding_cost,
            B_stockout_cost=user_B_stockout_cost,
        
            supplier_cost=user_supplier_cost,
            transfer_cost=user_transfer_cost
        )

    print("MDP Transition Map")
    print("------------------")
    print(si_mdp)

    # Boy this gets complicated...
    # Across all combinations of demand for both stores
    # Then across all possible existing orders for each store
    # Then finally across all possible betwee-store transfers
    fdp: FiniteDeterministicPolicy[InventoryState, Tuple[int,int,int]] =\
        FiniteDeterministicPolicy(
            {InventoryState(A_alpha, A_beta, B_alpha, B_beta): 
             [user_A_capacity - (A_alpha + A_beta), 
              user_B_capacity - (B_alpha + B_beta),
              transfer]
            for A_alpha in range(user_A_capacity + 1)
            for B_alpha in range(user_B_capacity + 1)
            for A_beta in range(user_A_capacity + 1 - A_alpha)
            for B_beta in range(user_B_capacity + 1 - B_alpha)
            for transfer in range(-min(B_alpha, user_A_capacity+1-A_alpha-A_beta),
                                   min(A_alpha, user_B_capacity+1-B_alpha-B_beta))
            }
    )
    
    
    # print("Keys:")
    # print(si_mdp.mapping.keys())
    
    print("Deterministic Policy Map")
    print("------------------------")
    print(fdp)

    implied_mrp: FiniteMarkovRewardProcess[InventoryState] =\
        si_mdp.apply_finite_policy(fdp)
    print("Implied MP Transition Map")
    print("--------------")
    print(FiniteMarkovProcess(
        {s.state: Categorical({s1.state: p for s1, p in v.table().items()})
         for s, v in implied_mrp.transition_map.items()}
    ))

    print("Implied MRP Transition Reward Map")
    print("---------------------")
    print(implied_mrp)

    print("Implied MP Stationary Distribution")
    print("-----------------------")
    implied_mrp.display_stationary_distribution()
    print()

    print("Implied MRP Reward Function")
    print("---------------")
    implied_mrp.display_reward_function()
    print()

    print("Implied MRP Value Function")
    print("--------------")
    implied_mrp.display_value_function(gamma=user_gamma)
    print()

    from rl.dynamic_programming import evaluate_mrp_result
    from rl.dynamic_programming import policy_iteration_result
    from rl.dynamic_programming import value_iteration_result

    print("Implied MRP Policy Evaluation Value Function")
    print("--------------")
    pprint(evaluate_mrp_result(implied_mrp, gamma=user_gamma))
    print()

    print("MDP Policy Iteration Optimal Value Function and Optimal Policy")
    print("--------------")
    opt_vf_pi, opt_policy_pi = policy_iteration_result(
        si_mdp,
        gamma=user_gamma
    )
    pprint(opt_vf_pi)
    print(opt_policy_pi)
    print()

    print("MDP Value Iteration Optimal Value Function and Optimal Policy")
    print("--------------")
    opt_vf_vi, opt_policy_vi = value_iteration_result(si_mdp, gamma=user_gamma)
    pprint(opt_vf_vi)
    print(opt_policy_vi)
    print()
# Out:
# MDP Transition Map
# ------------------
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1):
#   With Action (0, 0, -1):
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -13.579] with Probability 1.000
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -13.579] with Probability 1.000
#   With Action (0, 2, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -13.579] with Probability 1.000
#   With Action (0, 3, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3) and Reward -13.579] with Probability 1.000
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -13.579] with Probability 1.000
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -13.579] with Probability 1.000
#   With Action (1, 2, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -13.579] with Probability 1.000
#   With Action (1, 3, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3) and Reward -13.579] with Probability 1.000
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.236] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.371] with Probability 0.678
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.371] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.371] with Probability 0.678
#   With Action (0, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -7.371] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -7.371] with Probability 0.678
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.371] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.371] with Probability 0.678
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.371] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.371] with Probability 0.678
#   With Action (1, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -7.371] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -7.371] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.028] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.028] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.476] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.476] with Probability 0.352
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -5.476] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.476] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -5.476] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.476] with Probability 0.352
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.476] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.476] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.476] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.476] with Probability 0.352
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -5.476] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.476] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -5.476] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.476] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0):
#   With Action (0, 0, -1):
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -13.979] with Probability 1.000
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -13.979] with Probability 1.000
#   With Action (0, 2, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -13.979] with Probability 1.000
#   With Action (0, 3, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3) and Reward -13.979] with Probability 1.000
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -13.979] with Probability 1.000
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -13.979] with Probability 1.000
#   With Action (1, 2, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -13.979] with Probability 1.000
#   With Action (1, 3, -1):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3) and Reward -13.979] with Probability 1.000
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.636] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.771] with Probability 0.678
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.771] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.771] with Probability 0.678
#   With Action (0, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -7.771] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -7.771] with Probability 0.678
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.771] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.771] with Probability 0.678
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.771] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.771] with Probability 0.678
#   With Action (1, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -7.771] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -7.771] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=2):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.428] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.428] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.876] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.876] with Probability 0.352
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -5.876] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.876] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -5.876] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.876] with Probability 0.352
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.876] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.876] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.876] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.876] with Probability 0.352
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -5.876] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.876] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -5.876] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.876] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -12.036] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -8.171] with Probability 0.678
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -8.171] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -8.171] with Probability 0.678
#   With Action (0, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -8.171] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -8.171] with Probability 0.678
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -8.171] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -8.171] with Probability 0.678
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -8.171] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -8.171] with Probability 0.678
#   With Action (1, 2, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -8.171] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -8.171] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=1):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.828] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.828] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.276] with Probability 0.352
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -6.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -6.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.276] with Probability 0.352
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.276] with Probability 0.352
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -6.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -6.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.276] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=3, B_on_order=0):
#   With Action (0, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -6.228] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.228] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.676] with Probability 0.352
#   With Action (0, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -6.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -6.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.676] with Probability 0.352
#   With Action (1, 0, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.676] with Probability 0.352
#   With Action (1, 1, -1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -6.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -6.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.676] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0):
#   With Action (0, 0, 0):
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -13.679] with Probability 1.000
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -13.679] with Probability 1.000
#   With Action (0, 2, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -13.679] with Probability 1.000
#   With Action (0, 3, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3) and Reward -13.679] with Probability 1.000
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -13.679] with Probability 1.000
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -13.679] with Probability 1.000
#   With Action (1, 2, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -13.679] with Probability 1.000
#   With Action (1, 3, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3) and Reward -13.679] with Probability 1.000
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.336] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.471] with Probability 0.678
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.471] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.471] with Probability 0.678
#   With Action (0, 2, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -7.471] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -7.471] with Probability 0.678
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.471] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.471] with Probability 0.678
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.471] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.471] with Probability 0.678
#   With Action (1, 2, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -7.471] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -7.471] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.128] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.128] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.576] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.576] with Probability 0.352
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -5.576] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.576] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -5.576] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.576] with Probability 0.352
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.576] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.576] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.576] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.576] with Probability 0.352
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -5.576] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.576] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -5.576] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.576] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -3.234] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -3.234] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -3.234] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.407] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.407] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.407] with Probability 0.130
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -5.407] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.407] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.407] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.407] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.407] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.407] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.736] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.871] with Probability 0.678
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.871] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.871] with Probability 0.678
#   With Action (0, 2, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -7.871] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -7.871] with Probability 0.678
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.871] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.871] with Probability 0.678
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.871] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.871] with Probability 0.678
#   With Action (1, 2, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -7.871] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -7.871] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.528] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.528] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.976] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.976] with Probability 0.352
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -5.976] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.976] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -5.976] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.976] with Probability 0.352
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.976] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.976] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.976] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.976] with Probability 0.352
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -5.976] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.976] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -5.976] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.976] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=2):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -3.634] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -3.634] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -3.634] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.807] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.807] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.807] with Probability 0.130
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -5.807] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.807] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.807] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.807] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.807] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.807] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.928] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.928] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.376] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.376] with Probability 0.352
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -6.376] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.376] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -6.376] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.376] with Probability 0.352
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.376] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.376] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.376] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.376] with Probability 0.352
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -6.376] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.376] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -6.376] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.376] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=1):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -4.034] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -4.034] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -4.034] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.207] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.207] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -6.207] with Probability 0.130
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -6.207] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.207] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.207] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.207] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.207] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.207] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=3, B_on_order=0):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -4.434] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -4.434] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -4.434] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.607] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.607] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -6.607] with Probability 0.130
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -6.607] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.607] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.607] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.607] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.607] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.607] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=0):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.436] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.571] with Probability 0.678
#   With Action (0, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.571] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.571] with Probability 0.678
#   With Action (0, 2, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2) and Reward -7.571] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -7.571] with Probability 0.678
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.571] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.571] with Probability 0.678
#   With Action (1, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.571] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.571] with Probability 0.678
#   With Action (1, 2, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2) and Reward -7.571] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -7.571] with Probability 0.678
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=1):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.228] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.228] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.676] with Probability 0.352
#   With Action (0, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -5.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -5.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -5.676] with Probability 0.352
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.676] with Probability 0.352
#   With Action (1, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -5.676] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.676] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -5.676] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -5.676] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=2):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -3.334] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -3.334] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -3.334] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.507] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.507] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.507] with Probability 0.130
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -5.507] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.507] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.507] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.507] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.507] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.507] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=3):
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=0):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.628] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.628] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.076] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.076] with Probability 0.352
#   With Action (0, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -6.076] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.076] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -6.076] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -6.076] with Probability 0.352
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.076] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.076] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.076] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.076] with Probability 0.352
#   With Action (1, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -6.076] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.076] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -6.076] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -6.076] with Probability 0.352
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=1):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -3.734] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -3.734] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -3.734] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -5.907] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.907] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.907] with Probability 0.130
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -5.907] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.907] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.907] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -5.907] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -5.907] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -5.907] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=2):
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=0):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -4.134] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -4.134] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -4.134] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -6.307] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.307] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -6.307] with Probability 0.130
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -6.307] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.307] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.307] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -6.307] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -6.307] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.307] with Probability 0.130
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=1):
# From State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=3, B_on_order=0):
# From State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=0):
#   With Action (0, 0, 0):
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -14.279] with Probability 1.000
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -14.279] with Probability 1.000
#   With Action (0, 2, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2) and Reward -14.279] with Probability 1.000
#   With Action (0, 3, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3) and Reward -14.279] with Probability 1.000
#   With Action (1, 0, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -14.279] with Probability 1.000
#   With Action (1, 1, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -14.279] with Probability 1.000
#   With Action (1, 2, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2) and Reward -14.279] with Probability 1.000
#   With Action (1, 3, 0):
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3) and Reward -14.279] with Probability 1.000
# From State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=1):
#   With Action (0, 0, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -11.936] with Probability 0.322
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -8.071] with Probability 0.678
#   With Action (0, 1, 0):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -8.071] with Probability 0.322
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -8.071] with Probability 0.678
#   With Action (0, 2, 0):
# ...
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -6.707] with Probability 0.130
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=0, B_on_order=3):
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=0):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -6.828] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -6.828] with Probability 0.205
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -7.276] with Probability 0.352
#   With Action (0, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1) and Reward -7.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1) and Reward -7.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1) and Reward -7.276] with Probability 0.352
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -7.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.276] with Probability 0.352
#   With Action (1, 1, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1) and Reward -7.276] with Probability 0.256
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.276] with Probability 0.205
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1) and Reward -7.276] with Probability 0.187
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1) and Reward -7.276] with Probability 0.352
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=1):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -4.934] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -4.934] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -4.934] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.107] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -7.107] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -7.107] with Probability 0.130
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -7.107] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -7.107] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.107] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.107] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.107] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -7.107] with Probability 0.130
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=2):
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=2, B_on_order=0):
#   With Action (0, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0) and Reward -5.334] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -5.334] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -5.334] with Probability 0.076
#     To [Terminal State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=0) and Reward -7.507] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0) and Reward -7.507] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0) and Reward -7.507] with Probability 0.130
#   With Action (1, 0, 1):
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0) and Reward -7.507] with Probability 0.237
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -7.507] with Probability 0.189
#     To [State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.507] with Probability 0.076
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0) and Reward -7.507] with Probability 0.043
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0) and Reward -7.507] with Probability 0.325
#     To [State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0) and Reward -7.507] with Probability 0.130
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=2, B_on_order=1):
# From State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=3, B_on_order=0):
#
# Keys:
# dict_keys([NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=3)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=3, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=0, B_on_order=3)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=3, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=0, B_on_order=3)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=3, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=3)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=1)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=2)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=3)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0)), NonTerminal(state=InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1,  ...
# Deterministic Policy Map
# ------------------------
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=0): Do Action [2, 2, -1]
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=1): Do Action [2, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=1, B_on_order=2): Do Action [2, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=0): Do Action [1, 2, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=1): Do Action [1, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=1, B_on_order=2): Do Action [1, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=0): Do Action [0, 2, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=1): Do Action [0, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=1, B_on_order=2): Do Action [0, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=0): Do Action [2, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=2, B_on_order=1): Do Action [2, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=0): Do Action [1, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=2, B_on_order=1): Do Action [1, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=0): Do Action [0, 1, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=2, B_on_order=1): Do Action [0, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=3, B_on_order=0): Do Action [2, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=1, B_on_hand=3, B_on_order=0): Do Action [1, 0, -1]
# For State InventoryState(A_on_hand=0, A_on_order=2, B_on_hand=3, B_on_order=0): Do Action [0, 0, -1]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=0): Do Action [1, 3, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=1): Do Action [1, 2, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=2): Do Action [1, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=0, B_on_order=3): Do Action [1, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=0): Do Action [0, 3, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=1): Do Action [0, 2, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=2): Do Action [0, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=0, B_on_order=3): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=0): Do Action [1, 2, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=1): Do Action [1, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=1, B_on_order=2): Do Action [1, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=0): Do Action [0, 2, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=1): Do Action [0, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=1, B_on_order=2): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=0): Do Action [1, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=2, B_on_order=1): Do Action [1, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=0): Do Action [0, 1, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=2, B_on_order=1): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=0, B_on_hand=3, B_on_order=0): Do Action [1, 0, 0]
# For State InventoryState(A_on_hand=1, A_on_order=1, B_on_hand=3, B_on_order=0): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=0, B_on_order=0): Do Action [0, 3, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=0, B_on_order=1): Do Action [0, 2, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=0, B_on_order=2): Do Action [0, 1, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=0, B_on_order=3): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=0): Do Action [0, 2, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=1): Do Action [0, 1, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=1, B_on_order=2): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=2, B_on_order=0): Do Action [0, 1, 1]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=2, B_on_order=1): Do Action [0, 0, 0]
# For State InventoryState(A_on_hand=2, A_on_order=0, B_on_hand=3, B_on_order=0): Do Action [0, 0, 0]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/fj/qb_tch8j6sdg7th8gw7q9w000000gn/T/ipykernel_3942/801130808.py in <module>
#      65
#      66     implied_mrp: FiniteMarkovRewardProcess[InventoryState] =\
# ---> 67         si_mdp.apply_finite_policy(fdp)
#      68     print("Implied MP Transition Map")
#      69     print("--------------")
#
# ~/Desktop/CME241/RL-book/rl/markov_decision_process.py in apply_finite_policy(self, policy)
#     164             outcomes: DefaultDict[Tuple[S, float], float]\
#     165                 = defaultdict(float)
# --> 166             actions = policy.act(state)
#     167             for action, p_action in actions:
#     168                 for (s1, r), p in action_map[action].table().items():
#
# ~/Desktop/CME241/RL-book/rl/policy.py in act(self, state)
#      87
#      88     def act(self, state: NonTerminal[S]) -> FiniteDistribution[A]:
# ---> 89         return self.policy_map[state.state]
#      90
#      91
#
# KeyError: InventoryState(A_on_hand=0, A_on_order=0, B_on_hand=0, B_on_order=1)
